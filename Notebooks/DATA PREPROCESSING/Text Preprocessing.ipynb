# %% [markdown]
# # Tokenization, Stemming and other pre_processing of text

# %% [markdown]
# We'll import data into variables in memory. Sklearn has handy functions to load data files, we can use it here. It would  load data from the directroy structure we have for it into correct label variable (y_train) and data variable (text_train).

# %%
import os 
os.getcwd()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %%
#import dataset
df = pd.read_csv("TripAdvReview.csv", na_values=" ")

# %%
#remove extra columns and keep the necessary ones for analysis
df = pd.DataFrame(df.drop(['Bubble_Count', 'Review_Count'], axis=1))
df.columns
print(df.head(n=5))
# Out:
#                                                Title  Rating  Review_counts  \
# 0                            Vacation/Cottage Rental     5.0           85.0
# 1    Mistiso's Place Vacation Rentals- Purcell Suite     4.5          100.0
# 2  Toronto 4 Bedroom House Spacious Clean Beautif...     5.0           36.0
# 3                                   Our Sweet Escape     5.0           34.0
# 4    Walk to ocean from Lyons Cottage Rentals in PEI     4.5           48.0
#
#              City               Province  \
# 0   Niagara Falls                Ontario
# 1          Nelson       British Columbia
# 2         Toronto                Ontario
# 3  Qualicum Beach       British Columbia
# 4        Stanhope   Prince Edward Island
#
#                                              Reviews
# 0  1 \nThis rental felt more like a well-appointe...
# 1  4 \nI can't say enough about this beautiful an...
# 2  1 \nback yard! Would recommend the rental for ...
# 3  3 \nenjoyable. I have never stayed in a vacati...
# 4  2 \nquiet morning as we woke up - perfect vaca...

# %%
#remove new line characters from variable columns
df = df.replace(r'\n',' ', regex=True)

#remove the numbers in the review column
df.Reviews = df.Reviews.str.replace('\d+', '')

# %%
#fills the rating and Review_counts variable missing values with the mean and median respectively
df = df.fillna({'Rating': df.Rating.median(), 'Review_counts': df.Review_counts.mean()})

# %%
df.isnull().sum()
# Out:
# Title              0
# Rating             0
# Review_counts      0
# City               0
# Province           0
# Reviews          278
# dtype: int64

# %%
#drop all missing values
df.dropna(axis=0,how='any', inplace= True)
df.head(n=100)
# Out:
#                                                  Title  Rating  Review_counts  \
# 0                              Vacation/Cottage Rental     5.0           85.0
# 1      Mistiso's Place Vacation Rentals- Purcell Suite     4.5          100.0
# 2    Toronto 4 Bedroom House Spacious Clean Beautif...     5.0           36.0
# 3                                     Our Sweet Escape     5.0           34.0
# 4      Walk to ocean from Lyons Cottage Rentals in PEI     4.5           48.0
# 5                                 Best views in Nelson     5.0           33.0
# 6    Shale Beach House, Blue Mountain Collingwood Ont.     5.0           77.0
# 7                            Paradise Vacation Rentals     5.0           25.0
# 8                       Downtown Toronto 4BR Townhouse     5.0           55.0
# 9                              Les Rives du Sanctuaire     5.0           53.0
# 10   Inn Of The Sea Resort-Newly renovated, Oceanvi...     5.0           45.0
# 11   Enormous Riverfront 2 Bedroom Condo in the Hea...     5.0           87.0
# 12          Downtown Apartment in Historic Cabbagetown     5.0           39.0
# 13   Air-con 3 BR view suite for 6, w/ 50' 4K Smart TV     5.0           50.0
# 14          Downtown Toronto Furnished VACATION Rental     4.5           26.0
# 15   By the Vines 3 Bedroom 2 Bath Wine Country Get...     5.0          189.0
# 16                                 SURFS UP OCEANFRONT     5.0           33.0
# 17          Tigh-na Clayoquot Vacation House Tofino BC     5.0           30.0
# 25     I absolutely fell in love with this rental p...
# 26     to rent from. This is a vacation rental that...
# 27     vacation! Could not have been a better famil...
# 28     the twinkle of stars at night all combine to...
# 29     Trevor and company at AllSeason Vacation Ren...
# ..                                                 ...
# 70    The rental was a beautiful, clean, and roomy ...
# 71   The bed was very comfortable and gave us a goo...
# 72    We stayed at the Big Rock Vacation Rental in ...
# 73     This Vacation Rental was the second best thi...
# 74     friendly and a great host. I highly recommen...
# 75     lovely vacation there. It is peaceful, and c...
# 76     vacation rentals and came up with this choic...
# 77   cottage was great because unlike other rentals...
# 78     Greg and Jen of Far Horizons surely ensured ...
# 79     thought I would be spending part of a vacati...
# 80     We stayed at Cedar Ridge  for a family vacat...
# 82   equipped with every modern amenity you could h...
# 83   We go every year to John Anita's house rental ...
# 84    unreservedly recommend this vacation rental. ...
# 85     vacation homes in Trinity before for less th...
# 86     Black Rock Beach House is a great place for ...
# 87     fantastic vacation rental. I would definitel...
# 88   Hello Stacy and Ken, It was a true delight to ...
# 89     company. This truly was one of the best fami...
# 90     If you ever need to find a perfect example o...
# 91   recommend this cabin to anyone looking for a s...
# 92     I'm glad I booked this holiday rental it met...
# 93     when we are on vacation.....If you go to the...
# 94     find the rental unit. The unit is simply fur...
# 95    make all the difference. We are frequent visi...
# 96     were using. Nevertheless, we would definitel...
# 97    need for a family vacation and the location i...
# 98   We had a lovely time staying at Russell and Ch...
# 99     We have had ten wonderful summer vacations w...
# 100    unwind. Thanks for another memorable family ...
#
# [100 rows x 6 columns]

# %%
df.index=range(571)

# %%
print(df.shape)
df.isnull().sum()
# Out:
# (571, 6)
# Title            0
# Rating           0
# Review_counts    0
# City             0
# Province         0
# Reviews          0
# dtype: int64

# %%
df.head(n=100)
# Out:
#                                                 Title  Rating  Review_counts  \
# 0                             Vacation/Cottage Rental     5.0           85.0
# 1     Mistiso's Place Vacation Rentals- Purcell Suite     4.5          100.0
# 2   Toronto 4 Bedroom House Spacious Clean Beautif...     5.0           36.0
# 3                                    Our Sweet Escape     5.0           34.0
# 4     Walk to ocean from Lyons Cottage Rentals in PEI     4.5           48.0
# 5                                Best views in Nelson     5.0           33.0
# 6   Shale Beach House, Blue Mountain Collingwood Ont.     5.0           77.0
# 7                           Paradise Vacation Rentals     5.0           25.0
# 8                      Downtown Toronto 4BR Townhouse     5.0           55.0
# 9                             Les Rives du Sanctuaire     5.0           53.0
# 10  Inn Of The Sea Resort-Newly renovated, Oceanvi...     5.0           45.0
# 11  Enormous Riverfront 2 Bedroom Condo in the Hea...     5.0           87.0
# 12         Downtown Apartment in Historic Cabbagetown     5.0           39.0
# 13  Air-con 3 BR view suite for 6, w/ 50' 4K Smart TV     5.0           50.0
# 14         Downtown Toronto Furnished VACATION Rental     4.5           26.0
# 15  By the Vines 3 Bedroom 2 Bath Wine Country Get...     5.0          189.0
# 16                                SURFS UP OCEANFRONT     5.0           33.0
# 17         Tigh-na Clayoquot Vacation House Tofino BC     5.0           30.0
# 18  Howe Bay Beach House - PEI Oceanfront Vacation...     5.0           16.0
# 19                          Beach House on Square Bay     5.0           26.0
# 29    Trevor and company at AllSeason Vacation Ren...
# ..                                                ...
# 70   The rental was a beautiful, clean, and roomy ...
# 71  The bed was very comfortable and gave us a goo...
# 72   We stayed at the Big Rock Vacation Rental in ...
# 73    This Vacation Rental was the second best thi...
# 74    friendly and a great host. I highly recommen...
# 75    lovely vacation there. It is peaceful, and c...
# 76    vacation rentals and came up with this choic...
# 77  cottage was great because unlike other rentals...
# 78    Greg and Jen of Far Horizons surely ensured ...
# 79    thought I would be spending part of a vacati...
# 80    We stayed at Cedar Ridge  for a family vacat...
# 81  equipped with every modern amenity you could h...
# 82  We go every year to John Anita's house rental ...
# 83   unreservedly recommend this vacation rental. ...
# 84    vacation homes in Trinity before for less th...
# 85    Black Rock Beach House is a great place for ...
# 86    fantastic vacation rental. I would definitel...
# 87  Hello Stacy and Ken, It was a true delight to ...
# 88    company. This truly was one of the best fami...
# 89    If you ever need to find a perfect example o...
# 90  recommend this cabin to anyone looking for a s...
# 91    I'm glad I booked this holiday rental it met...
# 92    when we are on vacation.....If you go to the...
# 93    find the rental unit. The unit is simply fur...
# 94   make all the difference. We are frequent visi...
# 95    were using. Nevertheless, we would definitel...
# 96   need for a family vacation and the location i...
# 97  We had a lovely time staying at Russell and Ch...
# 98    We have had ten wonderful summer vacations w...
# 99    unwind. Thanks for another memorable family ...
#
# [100 rows x 6 columns]

# %%
# Let's understand the two lists: reviews (text_train) and their labels (y_train)
print("Type : ",type(df.Reviews))
print("Length of reviews: ",len(df.Reviews))
print("Review at index 6:\n ", df.Reviews[6])
print("Label of the review at Index 6: ",df.Rating[6])
# The ratings laels is a continous series of float numbers
# Out:
# Type :  <class 'pandas.core.series.Series'>
# Length of reviews:  571
# Review at index 6:
#     vacation spot! There are three levels and so each family got their very own
# Label of the review at Index 6:  5.0

# %%
#import libraries
import nltk
import re
from nltk.corpus import stopwords

# %%
print(df['Reviews'][1])
print(df['Reviews'][81])
# Out:
#   I can't say enough about this beautiful and charming vacation rental
# equipped with every modern amenity you could hope for while on vacation.

# %%
#filter punctuations, stemming and stopwords
corpus = []
for i in range(len(df)):
    review = re.sub('[^a-zA-Z0-9]', ' ', df['Reviews'][i])
    review = review.lower()
    tokenizer = nltk.tokenize.WhitespaceTokenizer()
    stemmer = nltk.PorterStemmer()
    lemmatizer = nltk.WordNetLemmatizer()
    tokens_list = tokenizer.tokenize(review)
    tokens = []
    for token in tokens_list:
        tokens.append(stemmer.stem(lemmatizer.lemmatize(token)))
        stop_words = stopwords.words("english")
    filtered_words = [w for w in tokens if w not in stop_words]
    review = ' '.join(filtered_words)
    corpus.append(review)

# %%
# Let's see if the text has been tokenize or not.
review[1]
# Out:
# 'a'

# %%
#Bag of Words model to convert corpus into X
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
cv.fit(corpus)
key = list(cv.vocabulary_.keys())
key.sort()
X = pd.DataFrame(cv.transform(corpus).toarray(),columns = key)
y = df.Rating

#TF_IDF model to convert corpus into X
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()

X2 = pd.DataFrame(tfidf.fit_transform(corpus).toarray())
